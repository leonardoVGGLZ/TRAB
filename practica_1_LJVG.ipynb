# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardoVGGLZ/TRAB/blob/main/practica_1_LJVG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sección nueva

# %% [markdown]
# VEGA GONZALEZ LEONARDO JESUS
#
# ![shutterstock_1078387013-scaled.jpg](data:image/jpeg;base64,...)

# %%
print("hola soy leonardo");
print(" tengo 16 años y estudio programacion");
print("quiero estudiar la carrera de programacion");
# Out:
# hola soy leonardo
#  tengo 16 años y estudio programacion
# quiero estudiar la carrera de programacion

# %%
kh=5
kg=3
r=kh+kg
print("tu resultado es : ",r );
# Out:
# tu resultado es :  8

# %%
nombre=input("ingresa tu nombre ")
print (nombre)
# Out:
# ingresa tu nombre g
# g
